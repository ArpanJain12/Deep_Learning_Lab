# %%
import numpy as np
import pandas as pd
import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2015-01-01", end="2024-01-01")

prices = data['Close'].values.reshape(-1, 1)
# Out:
# /tmp/ipykernel_3219/1553249475.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2015-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
scaler = MinMaxScaler()
prices = scaler.fit_transform(prices)

# %%
seq_len = 60

X = []
y = []

for i in range(seq_len, len(prices)):
    X.append(prices[i-seq_len:i])
    y.append(prices[i])

X = np.array(X)
y = np.array(y)

# %%
split = int(0.8 * len(X))

x_train = X[:split]
y_train = y[:split]

x_test = X[split:]
y_test = y[split:]

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(seq_len, 1)))
model.add(LSTM(50))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0094
# Epoch 2/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 3.9152e-04
# Epoch 3/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 3.6592e-04
# Epoch 4/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 3.2678e-04
# Epoch 5/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.4548e-04
# Epoch 6/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.7606e-04
# Epoch 7/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 3.0312e-04
# Epoch 8/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 2.9014e-04
# Epoch 9/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 2.6635e-04
# Epoch 10/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 3.5275e-04

# %%
pred = model.predict(x_test)
pred = scaler.inverse_transform(pred)
print(pred[:10])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
# [[166.03947]
#  [167.9476 ]
#  [169.39532]
#  [170.43141]
#  [171.40378]
#  [172.00162]
#  [172.10689]
#  [171.91605]
#  [171.39278]
#  [170.39627]]
